# %% [markdown]
# # Video Download Pipeline
#
# This notebook handles the automated downloading of YouTube videos from participant watch histories. It implements a robust downloading system with rate limiting, error handling, and comprehensive logging.
#
# ## Key Features:
# 1. Sample selection of 20 unique videos per participant
# 2. Controlled download speeds to prevent rate limiting
# 3. Authentication
# 4. Comprehensive logging of download attempts and outcomes
# 5. Automatic cleanup of unlogged/failed downloads
#
# ## Technical Specifications:
# - Download speed throttle: 200KB/s
# - Video format: Best quality at max 360p resolution
# - Wait time between downloads: 2-40 seconds
# - Sample size per participant: 20 videos
#
# ## Requirements:
# - Python packages:

# %%
! python3 -m pip install -U --pre "yt-dlp[default]" 
! python3 -m pip install scenedetect   # pip install scenedetect    #!{sys.executable} -m pip install scenedetect
! python3 -m pip install ffmpeg-python        # pip install ffmpeg         #!{sys.executable} -m pip install ffmpeg
! python3 -m pip install opencv-python # pip install opencv-python  #!{sys.executable} -m pip install opencv-python

# %%
# import libraries
import pandas as pd
import yt_dlp as yt
import os
import numpy as np
import time
import random
import json
import zipfile
import sys
import ffmpeg
from datetime import datetime
from download_utils import *
import random

sys.path.append('..')
from ytutils import *

# %% [markdown]
# - Authentication files:
#   - cookies.txt
#   - po-token_value.txt
#
#
#   For details on how to obtain these files, please refer to yt-dlp's documentation:
#   - [cookies.txt](https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp)
#   - [po-token_value.txt](https://github.com/yt-dlp/yt-dlp/wiki/PO-Token-Guide)
#
# ## Input/Output:
# - Input: Cleaned watch history CSV from Pre_Download pipeline
# - Output:
#   - Downloaded videos in MP4 format
#   - JSON metadata files
#   - Comprehensive download logs

# %% [markdown]
# ## Sampling & Downloading
# - per participant identify and download 20 unique videos that have not been downloaded yet
#     - download speed throttle: 200K
#     - format: best possible quality at max 360p resolution
#     - no subtitles
#     - wait time between downloads < 15s
# - skip participants where < 20 videos are available

# %%
def refresh_auth(auth_dir):
    po_token_path = os.path.join(auth_dir, "po-token_value.txt")
    cookie_file_path = os.path.join(auth_dir, "cookies.txt")
    
    # Load PO token and cookies
    try:
        with open(po_token_path, "r") as token_file:
            po_token = token_file.read().strip()
    except FileNotFoundError:
        raise FileNotFoundError(f"PO token file not found at {po_token_path}")

    if not os.path.exists(cookie_file_path):
        raise FileNotFoundError(f"Cookie file not found at {cookie_file_path}")

    return po_token, cookie_file_path

# %%
def download_video(video_id, download_dir, speed_limit, logger=None, po_token=None, cookie_file=None):
    """
    Downloads a YouTube video based on the provided video ID and saves it in the specified directory 
    with a set download speed limit and resolution (no av1 codec!!). Returns download status and a server response message.

    Parameters:
        video_id (str): Unique identifier of the video to download.
        download_dir (str): Directory where the video will be saved.
        speed_limit (int): Download rate limit in bytes per second.
        logger (class): class defined in download_utils. Will save all output from yt-dlp so it can be added to the logs.
        po_token (str): Personal OAuth token for authentication (if needed).
        cookie_file (str): Path to the cookie file (if needed).

    Returns:
        tuple: (bool, str) where the boolean indicates success (True) or failure (False), 
        the string provides a message detailing the outcome or error encountered, and the log of outputs (list).
    """
    # Ensure the output folder path ends with a separator
    if not download_dir.endswith(os.sep):
        download_dir += os.sep

    video_url = f"https://www.youtube.com/watch?v={video_id}"

    # Set options for downloading
    ydl_opts = {
        'ratelimit': speed_limit,
        'throttledratelimit': int(200 * 1024),  # Throttling limit
        'format': 'bv*[ext=mp4][height<=360][vcodec!*=av01]+ba[ext=m4a]/b[ext=mp4][height<=360][vcodec!*=av01]/b[ext=mp4][height<=360]/18',
        'outtmpl': os.path.join(download_dir, f'{video_id}.%(ext)s'),
        'noplaylist': True,
        'quiet': False,
        'verbose': True,
        'writeinfojson': True,
        'geo_bypass': True,
        'age_limit': 18,
        'retries': 3,
        'logger': logger,
        'cookiefile': cookie_file,
        'extractor_args': {'youtube': {'player_client': ['web'], 'po_token': [f"web.gsv+{po_token}"]}}, #'extractor_args': {'youtube': {'player_client': ['web'], 'po_token': [f"web+{po_token}"]}},
        'match_filter': lambda info: (
            "Skipping livestream (live or past live)" if info.get('is_live') or info.get('was_live') else None
        ),
    }


    try:
        # Use yt-dlp with the specified options
        with yt.YoutubeDL(ydl_opts) as ydl:
            ydl.download([video_url])

        log = logger.logs if logger else None
        return True, "Download successful", log

    except Exception as e:
        error_message = str(e)
        log = logger.logs if logger else None
        return False, error_message, log


# New main function sample and download
def download_unique_videos(df, download_dir, log_path, speed_limit, log_df, wait_time_range=(5, 10), sample_size=20, seed=42, auth_dir="Authentication"):
    """
    Downloads a specified number of unique videos for each participant from a watch history DataFrame, 
    logs the download attempts, and handles various download scenarios such as checking existing downloads 
    and logging entries. The function shuffles the unique videos for each participant before filtering out 
    any videos that have already been downloaded or attempted to insure reproducibility.

    Parameters:
        df (pd.DataFrame): Watch history DataFrame containing video data with columns for 'Participant ID' and 'video_id'.
        download_dir (str): Path to the directory where downloaded videos will be saved.
        log_path (str): Path to the directory where log files are stored and new entries will be created.
        speed_limit (int): Download rate limit in bytes per second to avoid overwhelming the server.
        wait_time_range (tuple): Range of wait time (in seconds) to pause between downloads to avoid 
                                 triggering rate limits (default is (5, 35)).
        sample_size (int): Target number of unique videos to download for each participant (default is 20).
        seed (int): Random seed for reproducibility in shuffling video lists (default is 42).

    Returns:
        pd.DataFrame: A concatenated DataFrame of log entries for all download attempts, capturing successes, 
                      failures, and insufficient video cases.

    Process Overview:
    - The function begins by setting a random seed for reproducibility and concatenates existing log files 
      to track previous downloads.
    - It iterates through each unique participant, checking for prior download attempts and ensuring sufficient 
      videos remain for downloading.
    - Unique videos for each participant are shuffled to randomize the download order before filtering out 
      videos that have been previously attempted or successfully downloaded.
    - The function downloads videos until the specified sample size is achieved (or no more videos are available), 
      logging each attempt's success or failure along with relevant timing information.
    - Random wait times are introduced between downloads to mitigate potential rate-limiting issues from the 
      video source.

    Notes:
        - The function creates log entries for each video download attempt, noting successes, failures, and 
          cases where participants do not have enough unique videos available.
        - If a participant has already met the sample size requirement, they are skipped in subsequent runs.
        - Ensures that each download is unique and that previously downloaded videos are not re-attempted.
        - Note that sometimes downloads is slowed to a halt regardles of video size (maybe something done on youtube's end)
    """
    random.seed(seed)  # Set the seed for reproducibility

    # get all participents
    participants = df['Participant ID'].unique()
    
    n_participants = len(participants)
    counter = 0

    for participant in participants:
        counter += 1

        # check if they have been logged as having  insufficiant videos
        if not_enough_videos(participant, log_path):
            print(f"Skipping Participant {participant}: Not enough videos. See log entry {f"{log_path}/insufficiant_vids_{participant}.log.csv"}")
            continue      
        
        # how many downloaded for this participant
        downloaded_count = nb_videos_downloaded(log_df, participant)
        
        if downloaded_count >= sample_size:
            print(f"Download already complete for participant {participant}.")
            continue

        participant_videos = df[df['Participant ID'] == participant]
        unique_videos = participant_videos.drop_duplicates(subset=['video_id'])

        needed_vids = sample_size - downloaded_count 

        if len(unique_videos) < needed_vids:
            m = f"Skipping Participant {participant}: Less than {needed_vids} unique video(s) left."
            print(m)
            make_log_entry(participant, None, False, m, now(), now(), log_path, exept=True)
            continue

        # randomly shuffle unique videos (with given random state)
        unique_videos = unique_videos.sample(frac=1, random_state=seed).reset_index(drop=True)

        # filter any videos that have previously been atempted downloaded (logged)
        unique_videos = unique_videos[~unique_videos['video_id'].apply(
            lambda vid: is_video_attempted_downloded(vid, log_path))]

        if len(unique_videos) < needed_vids:
            m = f"Skipping Participant {participant}: Fewer than {needed_vids} new videos to download."
            print(m)
            make_log_entry(participant, None, False, m, now(), now(), log_path, exept=True)
            continue

        video_list = unique_videos['video_id'].tolist()

        print(f"Downloading videos for Participant {participant}...")

        for video_id in video_list:
            if downloaded_count >= sample_size:
                break

            # we have videos that are downloaded but not logged
            if is_video_downloaded(video_id, download_dir):
                print(f"Video {video_id} already in download folder. Going to next video", flush=True)
                make_log_entry(participant, video_id, True, "Already in download folder", now(), now(), log_path)
                downloaded_count += 1
                continue

            print(f"Attempting download for video {video_id}", flush=True) 
            po_token, cookie_file = refresh_auth(auth_dir)
            
            my_logger = MyLogger() # Instantiate the logger
            start_time = now() # start timer
            success, server_reply, log = download_video(video_id, download_dir, speed_limit, my_logger, po_token, cookie_file)
            end_time = now() # end timer
            
            time_min = (end_time - start_time).total_seconds()/60
            print(f"video: {video_id}, result: {success}, time: {time_min:.2f} min, message: {server_reply}", flush=True)

            try:
                size = os.path.getsize(download_dir + f"/{video_id}.mp4")  # Get file size in bytes
            except FileNotFoundError:
                size = None

            info = get_video_info(video_id, download_dir)
            
            make_log_entry(participant, video_id, success, server_reply, start_time, end_time, log_path, log=log, size=size, info=info)
            
            if success:
                    downloaded_count += 1

            # Random wait between downloads (to avoid rate-limiting) 
            wait_time = random.uniform(*wait_time_range)
            print(f"Waiting for {wait_time:.2f} seconds...")
            time.sleep(wait_time)

        print(f"Done with participant number {counter} of {n_participants} ({round(counter/n_participants * 100, 2)}% completed)")
        print('─' * 20) 

    print("Download process completed.")
    return concatenate_logs(log_path)

# %%
clean_wh = pd.read_csv('clean_watch_history.csv')

# Ensure all entries in the "Participant ID" column are treated as strings
clean_wh['Participant ID'] = clean_wh['Participant ID'].astype(str)

# %%
download_dir = 'Downloads'
log_path = 'Log_Entries'
auth_dir= "Authentication"
log_df = concatenate_logs(log_path)

# %%
download_dir = 'Downloads'
log_path = 'Log_Entries'
auth_dir= "Authentication"

log_df = download_unique_videos(clean_wh, download_dir, log_path, speed_limit=int(800*1024), log_df=log_df, wait_time_range=(2, 40), sample_size=20, seed=42, auth_dir = "Authentication")

log_df.to_csv('Downloads_log.csv', index=False)
# Out:
# Download already complete for participant 26958.
# Download already complete for participant 20521.
# Download already complete for participant 17749.
# Download already complete for participant 20349.
# Download already complete for participant 24514.
# Download already complete for participant am84r.
# Download already complete for participant 1977.
# Download already complete for participant 18357.
# Download already complete for participant 21675.
# Download already complete for participant bjnn7.
# Download already complete for participant 38499.
# Download already complete for participant 37430.
# Download already complete for participant 2470.
# Download already complete for participant 13932.
# Download already complete for participant 29870.
# Download already complete for participant 17682.
# Download already complete for participant 7162.
# Download already complete for participant 19176.
# Download already complete for participant 14192.
# Download already complete for participant 7719.
# Download already complete for participant 24635.
# Download already complete for participant 27567.
# Download already complete for participant 7056.
# Download already complete for participant 30810.
# Download already complete for participant b1kwm.
# Download already complete for participant 29378.
# Download already complete for participant jbhsz.
# Download already complete for participant 14942.
# Download already complete for participant 18697.
# Download already complete for participant 19080.
# Download already complete for participant 22066.
# Download already complete for participant e90ob.
# Download already complete for participant 18419.
# Download already complete for participant 14199.
# Download already complete for participant 30366.
# Download already complete for participant 16972.
# Download already complete for participant cdvye.
# Download already complete for participant 11778.
# Download already complete for participant 26673.
# Download already complete for participant iw0kn.
# Download already complete for participant 19031.
# Download already complete for participant bhiuy.
# Download already complete for participant 32687.
# Download already complete for participant 20577.
# Download already complete for participant 7732.
# Skipping Participant 18198: Less than 20 unique video(s) left.
# Download already complete for participant 10961.
# Download already complete for participant 18526.
# Download already complete for participant 24479.
# Skipping Participant 36593: Fewer than 5 new videos to download.
# Skipping Participant 24340: Fewer than 20 new videos to download.
# Download already complete for participant 11967.
# Download already complete for participant 15597.
# Download already complete for participant 19466.
# Download already complete for participant 28207.
# Download already complete for participant 18231.
# Download already complete for participant 30022.
# Download already complete for participant bznis.
# Download already complete for participant 25729.
# Download already complete for participant 22186.
# Download already complete for participant 18434.
# Download already complete for participant aj48m.
# Download already complete for participant 17672.
# Download already complete for participant 13990.
# Download already complete for participant 32240.
# Download already complete for participant h92a5.
# Download already complete for participant 23185.
# Download already complete for participant 2395.
# Download already complete for participant 13874.
# Download already complete for participant 17558.
# Download already complete for participant 36955.
# Download already complete for participant 8593.
# Download already complete for participant 20703.
# Download already complete for participant 28737.
# Download already complete for participant 32418.
# Download already complete for participant 14984.
# Download already complete for participant 16875.
# Download already complete for participant 37014.
# Download already complete for participant bga1d.
# Download already complete for participant 13877.
# Download already complete for participant bh9fq.
# Download already complete for participant 17976.
# Download already complete for participant 11608.
# Download already complete for participant 18650.
# Download already complete for participant d85xe.
# Download already complete for participant 25569.
# Download already complete for participant 29438.
# Download already complete for participant 13929.
# Download already complete for participant 8279.
# Download already complete for participant 17996.
# Download already complete for participant 3540.
# Download already complete for participant 17787.
# Download already complete for participant 23608.
# Download already complete for participant 22044.
# Download already complete for participant egs2s.
# Download already complete for participant 5429.
# Download already complete for participant 6938.
# Download already complete for participant 15607.
# Download already complete for participant hgtxi.
# Download already complete for participant 20319.
# Download already complete for participant 18641.
# Download already complete for participant 24820.
# Download already complete for participant 10104.
# Download already complete for participant 9955.
# Download already complete for participant 37673.
# Download already complete for participant 4606.
# Download already complete for participant 23584.
# Download already complete for participant 3909.
# Download already complete for participant art0o.
# Download already complete for participant 8296.
# Download already complete for participant 18551.
# Download already complete for participant 8661.
# Download already complete for participant 4614.
# Download already complete for participant jgztb.
# Download already complete for participant 17811.
# Download already complete for participant 25662.
# Download already complete for participant g6a4k.
# Download already complete for participant 22681.
# Download already complete for participant 26163.
# Download already complete for participant 36374.
# Download already complete for participant afoux.
# Download already complete for participant 19181.
# Download already complete for participant 10516.
# Download already complete for participant 2449.
# Download already complete for participant 22291.
# Download already complete for participant aorav.
# Download already complete for participant 14040.
# Download already complete for participant 14573.
# Download already complete for participant a31jk.
# Download already complete for participant 8509.
# Download already complete for participant 25728.
# Download already complete for participant 36548.
# Download already complete for participant 18117.
# Download already complete for participant g2622.
# Download already complete for participant 4013.
# Download already complete for participant dyf9l.
# Download already complete for participant ijack.
# Download already complete for participant 37792.
# Download already complete for participant 6515.
# Download already complete for participant 18420.
# Download already complete for participant 22316.
# Download already complete for participant klv3k.
# Download already complete for participant 13449.
# Download already complete for participant 3240.
# Download already complete for participant etgsh.
# Download already complete for participant 6551.
# Download already complete for participant 26717.
# Download already complete for participant 14055.
# Download already complete for participant 5289.
# Download already complete for participant 7864.
# Download already complete for participant 29731.
# Download already complete for participant 6404.
# Download already complete for participant 5338.
# Download already complete for participant a4gd9.
# Download already complete for participant 33509.
# Download already complete for participant 20524.
# Download already complete for participant 9823.
# Download already complete for participant 22004.
# Download already complete for participant aliwt.
# Download already complete for participant e96u7.
# Download already complete for participant 1099.
# Download already complete for participant 27547.
# Download already complete for participant 10213.
# Download already complete for participant 23114.
# Download already complete for participant 18111.
# Download already complete for participant 6161.
# Download already complete for participant 8247.
# Download already complete for participant 23593.
# Download already complete for participant 19021.
# Download already complete for participant 33549.
# Download already complete for participant 20146.
# Download already complete for participant 2425.
# Download already complete for participant 3429.
# Download already complete for participant 23730.
# Download already complete for participant i9ejv.
# Download already complete for participant 29049.
# Download already complete for participant 18318.
# Download already complete for participant 1787.
# Download already complete for participant 23099.
# Download already complete for participant 1181.
# Download already complete for participant 14964.
# Download already complete for participant 17784.
# Download already complete for participant 27510.
# Download already complete for participant jmm3r.
# Download already complete for participant 27571.
# Download already complete for participant 19273.
# Download already complete for participant 7651.
# Download already complete for participant jjg6w.
# Download already complete for participant 19527.
# Download already complete for participant 5487.
# Download already complete for participant aoscl.
# Download already complete for participant 2703.
# Download already complete for participant 16629.
# Download already complete for participant 22208.
# Download already complete for participant 5785.
# Download already complete for participant 31265.
# Download already complete for participant 24529.
# Download already complete for participant 21740.
# Download already complete for participant 6224.
# Download already complete for participant 16456.
# Download already complete for participant 11564.
# Download already complete for participant 18170.
# Download already complete for participant 20555.
# Download already complete for participant 31858.
# Download already complete for participant 23598.
# Download already complete for participant 1138.
# Download already complete for participant ildq1.
# Download already complete for participant ap6ji.
# Download already complete for participant 3328.
# Download already complete for participant 17977.
# Download already complete for participant 30752.
# Download already complete for participant 18722.
# Download already complete for participant 18748.
# Download already complete for participant 16788.
# Download already complete for participant 22145.
# Download already complete for participant hd3p1.
# Download already complete for participant 19169.
# Download already complete for participant 6210.
# Download already complete for participant 6176.
# Download already complete for participant 22095.
# Download already complete for participant 19383.
# Download already complete for participant 30051.
# Download already complete for participant 23122.
# Download already complete for participant 18481.
# Download already complete for participant 7983.
# Download already complete for participant b9le3.
# Download already complete for participant 6885.
# Download already complete for participant 5456.
# Download already complete for participant 13483.
# Download already complete for participant 18947.
# Download already complete for participant 16963.
# Download already complete for participant 9523.
# Download already complete for participant 18680.
# Download already complete for participant 22282.
# Download already complete for participant 3384.
# Download already complete for participant 32212.
# Download already complete for participant 22160.
# Download already complete for participant 30557.
# Download already complete for participant 28852.
# Download already complete for participant 2671.
# Download already complete for participant 18328.
# Download already complete for participant 17739.
# Download already complete for participant 19665.
# Download already complete for participant 23581.
# Download already complete for participant 17125.
# Download already complete for participant 25555.
# Download already complete for participant 14756.
# Download already complete for participant jqj94.
# Download already complete for participant 38161.
# Download already complete for participant 18166.
# Download already complete for participant 7263.
# Download already complete for participant 17862.
# Download already complete for participant 9869.
# Download already complete for participant 22225.
# Download already complete for participant gtfkq.
# Download already complete for participant 22191.
# Download already complete for participant 8389.
# Download already complete for participant 4342.
# Download already complete for participant 22192.
# Download already complete for participant 21776.
# Download already complete for participant 18210.
# Download already complete for participant bzaix.
# Download already complete for participant 22103.
# Skipping Participant 19101: Less than 20 unique video(s) left.
# Download already complete for participant 30091.
# Download already complete for participant 14951.
# Download already complete for participant ag1zk.
# Download already complete for participant 30505.
# Download already complete for participant 35069.
# Download already complete for participant 19543.
# Download already complete for participant 36931.
# Download already complete for participant dxn9m.
# Download already complete for participant 2355.
# Download already complete for participant a6fum.
# Download already complete for participant 19082.
# Download already complete for participant d6gi3.
# Download already complete for participant boe6e.
# Download already complete for participant 36704.
# Download already complete for participant 22343.
# Download already complete for participant knkg9.
# Download already complete for participant 18162.
# Download already complete for participant 8734.
# Download already complete for participant ja6dn.
# Download already complete for participant 3287.
# Download already complete for participant 2687.
# Download already complete for participant 5408.
# Download already complete for participant 24413.
# Download already complete for participant 1903.
# Download already complete for participant 19058.
# Download already complete for participant 10404.
# Download already complete for participant 36936.
# Download already complete for participant 10773.
# Download already complete for participant 28077.
# Download already complete for participant jtjxf.
# Download already complete for participant agw9l.
# Download already complete for participant 30724.
# Download already complete for participant i1wpk.
# Download already complete for participant 31099.
# Download already complete for participant 13842.
# Download already complete for participant 22288.
# Download already complete for participant 1686.
# Download already complete for participant 30530.
# Download already complete for participant axozw.
# Download already complete for participant 13973.
# Download already complete for participant fam81.
# Download already complete for participant 19154.
# Download already complete for participant 19964.
# Download already complete for participant 17703.
# Download already complete for participant 22080.
# Download already complete for participant 24304.
# Download already complete for participant 28405.
# Download already complete for participant 20553.
# Download already complete for participant 38291.
# Download already complete for participant 21357.
# Download already complete for participant 5631.
# Download already complete for participant 27583.
# Download already complete for participant 26140.
# Download already complete for participant 18636.
# Download already complete for participant 24676.
# Download already complete for participant 17808.
# Download already complete for participant 9516.
# Download already complete for participant 2480.
# Download already complete for participant 14105.
# Download already complete for participant 12479.
# Download already complete for participant 18272.
# Download already complete for participant 4004.
# Download already complete for participant 3071.
# Download already complete for participant 3216.
# Download already complete for participant is7y4.
# Download already complete for participant 1851.
# Download already complete for participant 17955.
# Download already complete for participant 19103.
# Download already complete for participant 15111.
# Download already complete for participant 20673.
# Download already complete for participant 17519.
# Download already complete for participant 19065.
# Download already complete for participant 25682.
# Download already complete for participant 26042.
# Download already complete for participant 29867.
# Download already complete for participant 27657.
# Download already complete for participant 37144.
# Download already complete for participant 17641.
# Download already complete for participant 16499.
# Download already complete for participant as8nk.
# Download already complete for participant 22313.
# Download already complete for participant 23998.
# Download already complete for participant 32657.
# Download already complete for participant 20748.
# Download already complete for participant 11825.
# Download already complete for participant 32612.
# Download already complete for participant 3803.
# Download already complete for participant kwgd8.
# Download already complete for participant 20278.
# Download already complete for participant 22212.
# Download already complete for participant dayn2.
# Download already complete for participant 22436.
# Download already complete for participant 11714.
# Download already complete for participant 19028.
# Download already complete for participant 19479.
# Download already complete for participant 18217.
# Download already complete for participant 19102.
# Download already complete for participant 11265.
# Download already complete for participant 18384.
# Download already complete for participant 28521.
# Download already complete for participant 17701.
# Download already complete for participant 7772.
# Download already complete for participant 17892.
# Download already complete for participant 3052.
# Download already complete for participant 24043.
# Download already complete for participant azgab.
# Download already complete for participant 14719.
# Download already complete for participant 17509.
# Download already complete for participant bv41s.
# Download already complete for participant 19247.
# Download already complete for participant 22532.
# Download already complete for participant 27725.
# Download already complete for participant 13166.
# Download already complete for participant 17893.
# Download already complete for participant ilnb5.
# Download already complete for participant 23639.
# Download already complete for participant 18413.
# Download already complete for participant 20525.
# Download already complete for participant 1532.
# Download already complete for participant 20720.
# Download already complete for participant 26895.
# Download already complete for participant 18834.
# Download already complete for participant 31736.
# Download already complete for participant 7562.
# Download already complete for participant 18587.
# Download already complete for participant 23534.
# Download already complete for participant 37091.
# Download already complete for participant 6794.
# Download already complete for participant 14053.
# Download already complete for participant hb7hb.
# Download already complete for participant 38360.
# Download already complete for participant f0dbo.
# Download already complete for participant 21040.
# Download already complete for participant 11282.
# Download already complete for participant 31920.
# Download already complete for participant 21234.
# Download already complete for participant 4776.
# Download already complete for participant 27782.
# Download already complete for participant 11794.
# Download already complete for participant 31946.
# Download already complete for participant 9873.
# Download already complete for participant 5500.
# Download already complete for participant e2prz.
# Download already complete for participant 25688.
# Download already complete for participant 34522.
# Download already complete for participant 9702.
# Download already complete for participant bpxmx.
# Download already complete for participant 17651.
# Download already complete for participant 23653.
# Download already complete for participant 6187.
# Download already complete for participant 17552.
# Download already complete for participant 4517.
# Download already complete for participant 11784.
# Download already complete for participant 30827.
# Download already complete for participant 6582.
# Download already complete for participant d4hje.
# Download already complete for participant 3248.
# Download already complete for participant 34802.
# Download already complete for participant 1544.
# Download already complete for participant 19092.
# Download already complete for participant 12835.
# Download already complete for participant 17967.
# Download already complete for participant bwg5l.
# Download already complete for participant 26361.
# Download already complete for participant 23854.
# Download already complete for participant 16533.
# Download already complete for participant 10673.
# Download already complete for participant 16488.
# Download already complete for participant 24085.
# Download already complete for participant b3i5w.
# Download already complete for participant dgk2d.
# Download already complete for participant 19548.
# Download already complete for participant 10732.
# Download already complete for participant 5373.
# Download already complete for participant dou2w.
# Download already complete for participant 30509.
# Download already complete for participant 24791.
# Download already complete for participant 29657.
# Download already complete for participant 18721.
# Download already complete for participant 22123.
# Skipping Participant g3r0z: Less than 20 unique video(s) left.
# Download already complete for participant 2326.
# Download already complete for participant 7616.
# Download already complete for participant 30686.
# Download already complete for participant 16151.
# Download already complete for participant 14894.
# Download already complete for participant 23556.
# Download already complete for participant 31974.
# Download already complete for participant 11756.
# Download already complete for participant 20335.
# Download already complete for participant 24591.
# Download already complete for participant 22012.
# Download already complete for participant 27103.
# Download already complete for participant 9016.
# Download already complete for participant h8w52.
# Download already complete for participant 22222.
# Download already complete for participant a2ji0.
# Download already complete for participant 21869.
# Download already complete for participant 18358.
# Download already complete for participant 1188.
# Download already complete for participant 17510.
# Download already complete for participant 20839.
# Download already complete for participant 9828.
# Download already complete for participant 22065.
# Download already complete for participant 7046.
# Download already complete for participant 4631.
# Download already complete for participant 29672.
# Download already complete for participant g8fbr.
# Download already complete for participant 17751.
# Download already complete for participant 20785.
# Download already complete for participant 20630.
# Download already complete for participant 11110.
# Download already complete for participant 5563.
# Download already complete for participant 7706.
# Download already complete for participant 3900.
# Download already complete for participant 5621.
# Download already complete for participant 23691.
# Download already complete for participant bfc66.
# Download already complete for participant 23692.
# Download already complete for participant 23610.
# Download already complete for participant 1788.
# Download already complete for participant 7744.
# Download already complete for participant 9253.
# Download already complete for participant 18247.
# Download already complete for participant 10408.
# Download already complete for participant 15642.
# Download already complete for participant hkhe4.
# Download already complete for participant 1987.
# Download already complete for participant 16447.
# Download already complete for participant 18468.
# Download already complete for participant 16534.
# Download already complete for participant btf7h.
# Download already complete for participant 13497.
# Download already complete for participant 9426.
# Download already complete for participant 10351.
# Download already complete for participant 23538.
# Download already complete for participant 23542.
# Download already complete for participant a1ike.
# Download already complete for participant jnqgr.
# Download already complete for participant 16237.
# Download already complete for participant 0815aam0el.
# Download already complete for participant 5218.
# Download already complete for participant 23903.
# Download already complete for participant 17702.
# Download already complete for participant bste5.
# Download already complete for participant 31668.
# Download already complete for participant cu56j.
# Download already complete for participant 32438.
# Download already complete for participant 11816.
# Download already complete for participant 13269.
# Download already complete for participant 29160.
# Download already complete for participant ajrr7.
# Download already complete for participant 2323.
# Download already complete for participant 17173.
# Download already complete for participant 10731.
# Download already complete for participant 16475.
# Download already complete for participant 17943.
# Download already complete for participant 14542.
# Download already complete for participant 23727.
# Download already complete for participant 25213.
# Download already complete for participant 37836.
# Download already complete for participant 17575.
# Download already complete for participant iux69.
# Download already complete for participant 15015.
# Download already complete for participant 29207.
# Download already complete for participant 17557.
# Download already complete for participant 11875.
# Download already complete for participant 7657.
# Download already complete for participant ev3ez.
# Download already complete for participant 19369.
# Download already complete for participant 38088.
# Download already complete for participant 36686.
# Download already complete for participant 6623.
# Download already complete for participant 18775.
# Download already complete for participant 32775.
# Download already complete for participant 10395.
# Download already complete for participant 17522.
# Download already complete for participant bwzo4.
# Download already complete for participant dfez4.
# Download already complete for participant 18586.
# Download already complete for participant 14255.
# Download already complete for participant 18662.
# Download already complete for participant 18236.
# Download already complete for participant 23670.
# Download already complete for participant 9473.
# Download already complete for participant 6285.
# Downloading videos for Participant 17685...
# Attempting download for video okBqsKwrgqY
# video: okBqsKwrgqY, result: False, time: 0.02 min, message: ERROR: [youtube] okBqsKwrgqY: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Waiting for 22.38 seconds...
# Attempting download for video LEy4x-PTMqQ
# video: LEy4x-PTMqQ, result: False, time: 0.02 min, message: ERROR: [youtube] LEy4x-PTMqQ: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Waiting for 31.49 seconds...
# Attempting download for video zCAP03JO2aA
# video: zCAP03JO2aA, result: False, time: 0.01 min, message: ERROR: [youtube] zCAP03JO2aA: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Waiting for 38.90 seconds...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 5
#       2 log_path = 'Log_Entries'
#       3 auth_dir= "Authentication"
# ----> 5 log_df = download_unique_videos(clean_wh, download_dir, log_path, speed_limit=int(800*1024), wait_time_range=(2, 40), sample_size=20, seed=42, auth_dir = "Authentication")
#       7 log_df.to_csv('Downloads_log.csv', index=False)
#
# Cell In[5], line 192, in download_unique_videos(df, download_dir, log_path, speed_limit, wait_time_range, sample_size, seed, auth_dir)
#     190     wait_time = random.uniform(*wait_time_range)
#     191     print(f"Waiting for {wait_time:.2f} seconds...")
# --> 192     time.sleep(wait_time)
#     194 print(f"Done with participant number {counter} of {n_participants} ({round(counter/n_participants * 100, 2)}% completed)")
#     195 print('─' * 20)
#
# KeyboardInterrupt:

# %% [markdown]
# ---

# %%
def delete_unlogged_files(download_dir, log_df):
    # Step 1: Extract the video IDs from the log DataFrame
    logged_video_ids = set(log_df['video_id'].unique())  # Ensure unique video IDs
    removed_files = []
    # Step 2: Iterate over files in the download directory
    for filename in os.listdir(download_dir):
        if os.path.isdir(filename): # Skip directories (only delete files)
                continue
        # Extract the video ID (assuming filename format is 'video_id.mp4' or 'video_id.info.json' and so on)
        video_id = filename.split('.')[0]
        
        # Step 3: Delete files not in the log DataFrame
        if video_id not in logged_video_ids:
            file_path = os.path.join(download_dir, filename)
            os.remove(file_path)
            removed_files.append(filename)
            print(f"Deleted: {file_path}")
                
    with open("deleted_files.txt", "a") as file:
        for item in removed_files:
            file.write(f"{item}\n")

# %%
delete_unlogged_files("Downloads", log_df) # ! changed to "Downloads" during debugging. Original str uncertain
